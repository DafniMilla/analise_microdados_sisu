# %% [markdown]
# ## Exploração de dados

# %% [markdown]
# Essa linha importa a biblioteca pandas, usada para análise e manipulação de dados em Python.

# %%
import pandas as pd

# %% [markdown]
# Essa linha usa o **pandas** para carregar o arquivo CSV em um DataFrame chamado `microdados`, definindo o separador `|` e a codificação `ISO-8859-1` para ler corretamente os dados.

# %%
microdados=pd.read_csv("./dados/relatorio_chamada_regular_SISU_2010_1.csv", sep="|", encoding="ISO-8859-1")

# %% [markdown]
# Esse comando retorna os nomes das colunas do DataFrame `microdados`.

# %%
microdados.columns.values
# Out:
# array(['nu_ano', 'nu_edicao', 'ds_etapa', 'cod_ies', 'ies', 'sigla_ies',
#        'uf_ies', 'cod_campus', 'campus', 'uf_campus', 'municipio_campus',
#        'codigo_curso', 'nome_curso', 'grau', 'turno', 'tp_modalidade',
#        'ds_modalidade', 'qt_bonus_perc', 'nu_peso_l', 'nu_peso_ch',
#        'nu_peso_cn', 'nu_peso_m', 'nu_peso_r', 'nota_minima_l',
#        'nota_minima_ch', 'nota_minima_cn', 'nota_minima_m',
#        'nota_minima_r', 'media_minima', 'cpf', 'co_inscricao_enem',
#        'no_inscrito', 'tp_sexo', 'dt_nascimento', 'uf_origem',
#        'municipio_candidato', 'st_opcao', 'nu_nota_l', 'nu_nota_ch',
#        'nu_nota_cn', 'nu_nota_m', 'nu_nota_r', 'nota_l_com_peso',
#        'nota_ch_com_peso', 'nota_cn_com_peso', 'nota_m_com_peso',
#        'nota_r_com_peso', 'nota_concorrencia', 'nu_notacorte',
#        'nu_classificacao', 'st_aprovado', 'st_matricula', 'ds_matricula'],
#       dtype=object)

# %% [markdown]
# Aqui é criada a lista `colunasSelecionadas` com os nomes de interesse e, em seguida, o `read_csv` do **pandas** lê o arquivo importando apenas essas colunas, que são salvas no DataFrame `microdados`.

# %%
colunasSelecionadas=['nu_ano', 'ds_etapa','cod_ies', 'ies','uf_ies', 'campus','uf_campus', 'municipio_campus', 'nome_curso','grau','turno','tp_modalidade',
                      'tp_sexo', 'uf_origem','municipio_candidato','st_opcao','nota_concorrencia','nu_notacorte',
                      'st_aprovado','st_matricula', 'nu_peso_l', 'nu_peso_ch',
                    'nu_peso_cn', 'nu_peso_m', 'nu_peso_r', 'nota_minima_l',
                    'nota_minima_ch', 'nota_minima_cn', 'nota_minima_m', 'dt_nascimento',
                    'nota_minima_r', 'media_minima']
microdados= pd.read_csv("./dados/relatorio_chamada_regular_SISU_2010_1.csv", sep="|", encoding="ISO-8859-1" ,  usecols= colunasSelecionadas)

# %% [markdown]
# O comando `microdados.head()` mostra as primeiras 5 linhas do DataFrame, facilitando a visualização inicial dos dados.

# %%
microdados.head()
# Out:
#    nu_ano     ds_etapa  cod_ies  \
# 0    2010  1Âª CHAMADA      587
# 1    2010  2Âª CHAMADA      587
# 2    2010  3Âª CHAMADA      587
# 3    2010  1Âª CHAMADA     1303
# 4    2010  1Âª CHAMADA     5322
#
#                                                  ies uf_ies  \
# 0           UNIVERSIDADE FEDERAL RURAL DE PERNAMBUCO     PE
# 1           UNIVERSIDADE FEDERAL RURAL DE PERNAMBUCO     PE
# 2           UNIVERSIDADE FEDERAL RURAL DE PERNAMBUCO     PE
# 3  INSTITUTO FEDERAL DE EDUCAÃÃO, CIÃNCIA E TE...     GO
# 4  FUNDAÃÃO UNIVERSIDADE FEDERAL DO PAMPA - UNI...     RS
#
#                                               campus uf_campus  \
# 0  Recife-PE, Rua Dom Manoel de Medeiros, Dois Ir...        PE
# 1  Recife-PE, Rua Dom Manoel de Medeiros, Dois Ir...        PE
# 2  Recife-PE, Rua Dom Manoel de Medeiros, Dois Ir...        PE
# 3            Morrinhos-GO, BR 153 KM 633, ZONA RURAL        GO
# 4     Dom Pedrito-RS, Rua Borges de Medeiros, Centro        RS
#
#   municipio_campus              nome_curso          grau  ... media_minima  \
# 0           Recife               Zootecnia   Bacharelado  ...       750,96
# 1           Recife   CiÃªncias BiolÃ³gicas  Licenciatura  ...       750,96
# 2           Recife   CiÃªncias BiolÃ³gicas   Bacharelado  ...       750,96
# 3        Morrinhos  Sistemas para Internet  TecnolÃ³gico  ...       802,98
# 4      Dom Pedrito               Zootecnia   Bacharelado  ...       723,78
#
#   tp_sexo dt_nascimento uf_origem municipio_candidato st_opcao  \
# 0       M          1991        PE            PAULISTA        1
# 1       M          1991        PE            PAULISTA        1
# 2       M          1991        PE            PAULISTA        1
# 3       M          1988        GO            GOIATUBA        1
# 4       M          1990        TO          TAGUATINGA        1
#
#   nota_concorrencia nu_notacorte st_aprovado st_matricula
# 0            607,18       671,75           N            N
# 1            607,18       669,95           N            N
# 2            613,42       669,16           N            N
# 3            680,70       659,92           S            S
# 4            602,46       620,62           N            N
#
# [5 rows x 32 columns]

# %% [markdown]
# Mostra as últimas linhas

# %%
microdados.tail()
# Out:
#          nu_ano     ds_etapa  cod_ies  \
# 1670507    2010  1Âª CHAMADA      107
# 1670508    2010  1Âª CHAMADA      634
# 1670509    2010  2Âª CHAMADA     1166
# 1670510    2010  3Âª CHAMADA     1166
# 1670511    2010  1Âª CHAMADA     1810
#
#                                                        ies uf_ies  \
# 1670507         UNIVERSIDADE FEDERAL DE SÃO JOÃO DEL REI     MG
# 1670508                    UNIVERSIDADE FEDERAL DE PELOTAS     RS
# 1670509  INSTITUTO FEDERAL DE EDUCAÃÃO, CIÃNCIA E TE...     PB
# 1670510  INSTITUTO FEDERAL DE EDUCAÃÃO, CIÃNCIA E TE...     PB
# 1670511  INSTITUTO FEDERAL DE EDUCAÃÃO, CIÃNCIA E TE...     SP
#
#                                                     campus uf_campus  \
# 1670507  SÃ£o JoÃ£o del Rei-MG, PraÃ§a Dom HelvÃ©cio, D...        MG
# 1670508             Pelotas-RS, Rua Gomes Carneiro, Centro        RS
# 1670509  JoÃ£o Pessoa-PB, AVENIDA PRIMEIRO DE MAIO, JAG...        PB
# 1670510  JoÃ£o Pessoa-PB, AVENIDA PRIMEIRO DE MAIO, JAG...        PB
# 1670511         SÃ£o Paulo-SP, Rua Pedro Vicente, CanindÃ©        SP
#
#            municipio_campus                              nome_curso  \
# 1670507  SÃ£o JoÃ£o del Rei                              Psicologia
# 1670508             Pelotas                                 Direito
# 1670509        JoÃ£o Pessoa                    Design de Interiores
# 1670510        JoÃ£o Pessoa                    Design de Interiores
# 1670511          SÃ£o Paulo  AnÃ¡lise e Desenvolvimento de Sistemas
#
#                  grau  ... media_minima tp_sexo dt_nascimento uf_origem  \
# 1670507   Bacharelado  ...       677,00       F          1992        SP
# 1670508   Bacharelado  ...       674,96       F          1992        MS
# 1670509  TecnolÃ³gico  ...       674,96       F          1992        MS
# 1670510  TecnolÃ³gico  ...       674,96       F          1992        MS
# 1670511  TecnolÃ³gico  ...       794,56       F          1992        SP
#
#         municipio_candidato st_opcao nota_concorrencia nu_notacorte  \
# 1670507              FRANCA        1            570,44       764,24
# 1670508        CAMPO GRANDE        1            558,36       758,94
# 1670509        CAMPO GRANDE        1            567,10       641,06
# 1670510        CAMPO GRANDE        1            567,10       616,39
# 1670511           SAO PAULO        1            677,30       729,50
#
#         st_aprovado st_matricula
# 1670507           N            N
# 1670508           N            N
# 1670509           N            N
# 1670510           N            N
# 1670511           N            N
#
# [5 rows x 32 columns]

# %% [markdown]
# Esse trecho cria um dicionário chamado `modalidade`, onde cada código (A, V, L, B) é associado à sua descrição completa.

# %%
modalidade={
    "A": "Ampla concorrência",
    "V": "Escola pública",
    'L': 'PPI + Escola pública',
    'B': 'Residência em um dos municípios da Macrorregião Estado do Ceará',
    


}

# %% [markdown]
# Resumo da estrutura da base de dados, indicando as colunas, os tipos de dados, a quantidade de valores preenchidos e o uso de memória.

# %%
microdados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1670512 entries, 0 to 1670511
# Data columns (total 32 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   nu_ano               1670512 non-null  int64
#  1   ds_etapa             1670512 non-null  object
#  2   cod_ies              1670512 non-null  int64
#  3   ies                  1670512 non-null  object
#  4   uf_ies               1670512 non-null  object
#  5   campus               1670512 non-null  object
#  6   uf_campus            1670512 non-null  object
#  7   municipio_campus     1670512 non-null  object
#  8   nome_curso           1670512 non-null  object
#  9   grau                 1670512 non-null  object
#  10  turno                1670512 non-null  object
#  11  tp_modalidade        1670512 non-null  object
#  12  nu_peso_l            1670512 non-null  object
#  13  nu_peso_ch           1670512 non-null  object
#  14  nu_peso_cn           1670512 non-null  object
#  15  nu_peso_m            1670512 non-null  object
#  16  nu_peso_r            1670512 non-null  object
#  17  nota_minima_l        1670512 non-null  object
#  18  nota_minima_ch       1670512 non-null  object
#  19  nota_minima_cn       1670512 non-null  object
#  20  nota_minima_m        1670512 non-null  object
#  21  nota_minima_r        1670512 non-null  object
#  22  media_minima         1670512 non-null  object
#  23  tp_sexo              1670512 non-null  object
#  24  dt_nascimento        1670512 non-null  int64
#  25  uf_origem            1670512 non-null  object
#  26  municipio_candidato  1670512 non-null  object
#  27  st_opcao             1670512 non-null  int64
#  28  nota_concorrencia    1670512 non-null  object
#  29  nu_notacorte         1666822 non-null  object
#  30  st_aprovado          1670512 non-null  object
#  31  st_matricula         1670512 non-null  object
# dtypes: int64(4), object(28)
# memory usage: 407.8+ MB

# %% [markdown]
# conta o número de valores ausentes(nulos ou NaN)em cada coluna

# %%
microdados.isnull().sum()
# Out:
# nu_ano                    0
# ds_etapa                  0
# cod_ies                   0
# ies                       0
# uf_ies                    0
# campus                    0
# uf_campus                 0
# municipio_campus          0
# nome_curso                0
# grau                      0
# turno                     0
# tp_modalidade             0
# nu_peso_l                 0
# nu_peso_ch                0
# nu_peso_cn                0
# nu_peso_m                 0
# nu_peso_r                 0
# nota_minima_l             0
# nota_minima_ch            0
# nota_minima_cn            0
# nota_minima_m             0
# nota_minima_r             0
# media_minima              0
# tp_sexo                   0
# dt_nascimento             0
# uf_origem                 0
# municipio_candidato       0
# st_opcao                  0
# nota_concorrencia         0
# nu_notacorte           3690
# st_aprovado               0
# st_matricula              0
# dtype: int64
